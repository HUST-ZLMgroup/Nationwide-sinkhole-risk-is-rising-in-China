# %% [markdown]
# # Pearson / Spearman 相关性网络图（12变量，v6）
#
# 本 notebook 在 v5 基础上继续调整：
# - 保留 Pearson 与 Spearman
# - 保留标题、节点标签、色条刻度与色条标签
# - 删除 Kendall
# - 线条减薄
# - 新增 TAS 与 HUSS
# - SVG 文本保持为可编辑文本，不转曲，不嵌入字体
# - 字体指定为 Times New Roman

# %%
from pathlib import Path
import sys

data_path = "/mnt/data/AllFeatures_Positive_Negative_balanced_25366_ssp1_cleaned.csv"
script_path = "/mnt/data/pearson_spearman_code_v6_12vars_twopanel_editable_svg.py"
out_dir = "/mnt/data/pearson_spearman_12vars_twopanel_output_v6_editable_text"

print("data_path =", data_path)
print("script_path =", script_path)
print("out_dir =", out_dir)

# %%
import subprocess, shlex

cmd = [
    "python", script_path,
    "--data_path", data_path,
    "--out_dir", out_dir
]
print("Running:", " ".join(shlex.quote(x) for x in cmd))
subprocess.run(cmd, check=True)
print("Done.")

# %%
from pathlib import Path

for p in sorted(Path(out_dir).rglob("*")):
    if p.is_file():
        print(p)
